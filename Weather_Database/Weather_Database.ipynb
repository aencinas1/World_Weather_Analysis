# %%
import pandas as pd
from citipy import citipy
import requests
import numpy as np
from config import api
from datetime import datetime
import matplotlib.pyplot as plt
from scipy import stats

# %%
#create set of random lat and long combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add lats and lngs to a list
coordinates = list(lat_lngs)

# %%
#create a list for holding cities
cities = []
#id the nearest city for each lat and long comb
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

#print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api

# %%
#create empty list to hold weather data
city_data = []
#print the beginning fo the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

#create counters
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | poum
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | takaka
# Processing Record 6 of Set 1 | bonthe
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | fernley
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 1 | labuhan
# Processing Record 12 of Set 1 | shakawe
# Processing Record 13 of Set 1 | denpasar
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | beringovskiy
# Processing Record 16 of Set 1 | ilulissat
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | santa cruz
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | vilya
# Processing Record 23 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | bundaberg
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | hvide sande
# Processing Record 28 of Set 1 | sehithwa
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | kruisfontein
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | klaksvik
# Processing Record 33 of Set 1 | vanavara
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | mahanoro
# Processing Record 36 of Set 1 | fort nelson
# Processing Record 37 of Set 1 | souillac
# Processing Record 38 of Set 1 | pedernales
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | misratah
# Processing Record 42 of Set 1 | saint anthony
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | port lincoln
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | port blair
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | oktyabrskiy
# Processing Record 1 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 2 | ubrique
# Processing Record 3 of Set 2 | tura
# Processing Record 4 of Set 2 | harper
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | lingyuan
# Processing Record 7 of Set 2 | santa cruz del norte
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | husavik
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | axim
# Processing Record 14 of Set 2 | posse
# Processing Record 15 of Set 2 | alcamo
# Processing Record 16 of Set 2 | kloulklubed
# Processing Record 17 of Set 2 | sarangani
# Processing Record 18 of Set 2 | alyangula
# Processing Record 19 of Set 2 | batemans bay
# Processing Record 20 of Set 2 | emba
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | cayenne
# Processing Record 23 of Set 2 | pasan
# Processing Record 24 of Set 2 | hofn
# Processing Record 25 of Set 2 | cerrito
# Processing Record 26 of Set 2 | unye
# City not found. Skipping...
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | sile
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | beyneu
# Processing Record 31 of Set 2 | pamfila
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | monrovia
# Processing Record 34 of Set 2 | florianopolis
# Processing Record 35 of Set 2 | wapi pathum
# Processing Record 36 of Set 2 | prince rupert
# Processing Record 37 of Set 2 | igrim
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | dwarka
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | champerico
# Processing Record 42 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | castro
# Processing Record 45 of Set 2 | clyde river
# Processing Record 46 of Set 2 | kalmunai
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | grand gaube
# Processing Record 50 of Set 2 | jibuti
# Processing Record 1 of Set 3 | yanam
# Processing Record 2 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 3 | mount isa
# Processing Record 4 of Set 3 | roald
# Processing Record 5 of Set 3 | vanimo
# Processing Record 6 of Set 3 | kyra
# Processing Record 7 of Set 3 | baykit
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | malatya
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | kamien pomorski
# Processing Record 12 of Set 3 | dothan
# Processing Record 13 of Set 3 | moose factory
# Processing Record 14 of Set 3 | nouadhibou
# Processing Record 15 of Set 3 | hobart
# Processing Record 16 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 3 | samfya
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | esperance
# Processing Record 22 of Set 3 | hasaki
# Processing Record 23 of Set 3 | chumikan
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | aasiaat
# Processing Record 26 of Set 3 | faanui
# Processing Record 27 of Set 3 | lagoa
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | moyale
# Processing Record 30 of Set 3 | busselton
# Processing Record 31 of Set 3 | barrow
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | yulara
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | ixtapa
# Processing Record 36 of Set 3 | orumiyeh
# Processing Record 37 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 3 | alofi
# Processing Record 39 of Set 3 | blythe
# Processing Record 40 of Set 3 | pangnirtung
# Processing Record 41 of Set 3 | dossor
# Processing Record 42 of Set 3 | perove
# Processing Record 43 of Set 3 | herat
# Processing Record 44 of Set 3 | qasigiannguit
# Processing Record 45 of Set 3 | villa carlos paz
# Processing Record 46 of Set 3 | kerema
# Processing Record 47 of Set 3 | chachapoyas
# Processing Record 48 of Set 3 | caravelas
# Processing Record 49 of Set 3 | port elizabeth
# Processing Record 50 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 4 | touros
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | broome
# Processing Record 5 of Set 4 | fare
# Processing Record 6 of Set 4 | carnarvon
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | guano
# Processing Record 9 of Set 4 | puri
# Processing Record 10 of Set 4 | andrews
# Processing Record 11 of Set 4 | shatrovo
# Processing Record 12 of Set 4 | ambilobe
# Processing Record 13 of Set 4 | hubli
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | basoko
# Processing Record 16 of Set 4 | bandarbeyla
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | geraldton
# Processing Record 19 of Set 4 | mizdah
# Processing Record 20 of Set 4 | saint george
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | gamba
# Processing Record 23 of Set 4 | kaitangata
# Processing Record 24 of Set 4 | oyotun
# Processing Record 25 of Set 4 | nuuk
# Processing Record 26 of Set 4 | vardo
# Processing Record 27 of Set 4 | at-bashi
# Processing Record 28 of Set 4 | pacific grove
# Processing Record 29 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | padang
# Processing Record 32 of Set 4 | riyadh
# Processing Record 33 of Set 4 | olafsvik
# Processing Record 34 of Set 4 | troitsko-pechorsk
# Processing Record 35 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 36 of Set 4 | linqiong
# Processing Record 37 of Set 4 | poso
# Processing Record 38 of Set 4 | hamilton
# Processing Record 39 of Set 4 | mufumbwe
# Processing Record 40 of Set 4 | erenhot
# Processing Record 41 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 4 | morondava
# Processing Record 43 of Set 4 | tuatapere
# Processing Record 44 of Set 4 | chippewa falls
# Processing Record 45 of Set 4 | burica
# City not found. Skipping...
# Processing Record 46 of Set 4 | le lorrain
# Processing Record 47 of Set 4 | ellensburg
# Processing Record 48 of Set 4 | winnemucca
# Processing Record 49 of Set 4 | yarmouth
# Processing Record 50 of Set 4 | abha
# Processing Record 1 of Set 5 | lorengau
# Processing Record 2 of Set 5 | sungairaya
# Processing Record 3 of Set 5 | san cristobal
# Processing Record 4 of Set 5 | northam
# Processing Record 5 of Set 5 | east london
# Processing Record 6 of Set 5 | chatham
# Processing Record 7 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 8 of Set 5 | riberalta
# Processing Record 9 of Set 5 | kenai
# Processing Record 10 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 5 | khatanga
# Processing Record 12 of Set 5 | ipixuna
# Processing Record 13 of Set 5 | jalu
# Processing Record 14 of Set 5 | rio grande
# Processing Record 15 of Set 5 | mendahara
# City not found. Skipping...
# Processing Record 16 of Set 5 | mbouda
# Processing Record 17 of Set 5 | dingle
# Processing Record 18 of Set 5 | inongo
# Processing Record 19 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 5 | sortland
# Processing Record 21 of Set 5 | dikson
# Processing Record 22 of Set 5 | afua
# Processing Record 23 of Set 5 | mehamn
# Processing Record 24 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 5 | zhicheng
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | shache
# Processing Record 28 of Set 5 | comodoro rivadavia
# Processing Record 29 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 5 | palmer
# Processing Record 31 of Set 5 | tual
# Processing Record 32 of Set 5 | shar
# Processing Record 33 of Set 5 | seoul
# Processing Record 34 of Set 5 | lufilufi
# Processing Record 35 of Set 5 | valparaiso
# Processing Record 36 of Set 5 | ishigaki
# Processing Record 37 of Set 5 | marfino
# Processing Record 38 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 5 | sorland
# Processing Record 40 of Set 5 | magistralnyy
# Processing Record 41 of Set 5 | sitka
# Processing Record 42 of Set 5 | chilmari
# Processing Record 43 of Set 5 | ajdabiya
# Processing Record 44 of Set 5 | upington
# Processing Record 45 of Set 5 | san patricio
# Processing Record 46 of Set 5 | joensuu
# Processing Record 47 of Set 5 | natal
# Processing Record 48 of Set 5 | rawson
# Processing Record 49 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 5 | jumla
# Processing Record 1 of Set 6 | griffith
# Processing Record 2 of Set 6 | forestville
# Processing Record 3 of Set 6 | bertoua
# Processing Record 4 of Set 6 | hami
# Processing Record 5 of Set 6 | puerto escondido
# Processing Record 6 of Set 6 | marzuq
# Processing Record 7 of Set 6 | anzio
# Processing Record 8 of Set 6 | laguna
# Processing Record 9 of Set 6 | vila velha
# Processing Record 10 of Set 6 | tabas
# Processing Record 11 of Set 6 | hovd
# Processing Record 12 of Set 6 | heyang
# Processing Record 13 of Set 6 | krasnyy yar
# Processing Record 14 of Set 6 | usinsk
# Processing Record 15 of Set 6 | vila franca do campo
# Processing Record 16 of Set 6 | leh
# Processing Record 17 of Set 6 | nanortalik
# Processing Record 18 of Set 6 | belgrade
# Processing Record 19 of Set 6 | flin flon
# Processing Record 20 of Set 6 | zyryanka
# Processing Record 21 of Set 6 | acapulco
# Processing Record 22 of Set 6 | lebanon
# Processing Record 23 of Set 6 | likasi
# Processing Record 24 of Set 6 | la linea
# Processing Record 25 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 26 of Set 6 | saskylakh
# Processing Record 27 of Set 6 | pitimbu
# Processing Record 28 of Set 6 | wad madani
# Processing Record 29 of Set 6 | khani
# Processing Record 30 of Set 6 | strezhevoy
# Processing Record 31 of Set 6 | oktyabrskoye
# Processing Record 32 of Set 6 | birin
# Processing Record 33 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | wagar
# Processing Record 36 of Set 6 | rincon
# Processing Record 37 of Set 6 | norman wells
# Processing Record 38 of Set 6 | ciudad bolivar
# Processing Record 39 of Set 6 | huescar
# Processing Record 40 of Set 6 | chernyshevskiy
# Processing Record 41 of Set 6 | el angel
# Processing Record 42 of Set 6 | tasiilaq
# Processing Record 43 of Set 6 | conakry
# Processing Record 44 of Set 6 | berlevag
# Processing Record 45 of Set 6 | bathsheba
# Processing Record 46 of Set 6 | constitucion
# Processing Record 47 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 6 | bafq
# Processing Record 49 of Set 6 | romny
# Processing Record 50 of Set 6 | narsaq
# Processing Record 1 of Set 7 | victoria
# Processing Record 2 of Set 7 | horsham
# Processing Record 3 of Set 7 | ternate
# Processing Record 4 of Set 7 | cervo
# Processing Record 5 of Set 7 | luanda
# Processing Record 6 of Set 7 | mount gambier
# Processing Record 7 of Set 7 | fereydunshahr
# Processing Record 8 of Set 7 | nova soure
# Processing Record 9 of Set 7 | mindelo
# Processing Record 10 of Set 7 | sabang
# Processing Record 11 of Set 7 | kenora
# Processing Record 12 of Set 7 | goderich
# Processing Record 13 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 7 | baherden
# Processing Record 15 of Set 7 | mahebourg
# Processing Record 16 of Set 7 | ahipara
# Processing Record 17 of Set 7 | lazaro cardenas
# Processing Record 18 of Set 7 | maragogi
# Processing Record 19 of Set 7 | phulabani
# Processing Record 20 of Set 7 | navirai
# Processing Record 21 of Set 7 | byron bay
# Processing Record 22 of Set 7 | yatou
# Processing Record 23 of Set 7 | port-gentil
# Processing Record 24 of Set 7 | kibala
# Processing Record 25 of Set 7 | sandpoint
# Processing Record 26 of Set 7 | muscat
# Processing Record 27 of Set 7 | sao joao da barra
# Processing Record 28 of Set 7 | mirabad
# Processing Record 29 of Set 7 | gat
# Processing Record 30 of Set 7 | tawau
# Processing Record 31 of Set 7 | port keats
# Processing Record 32 of Set 7 | tabriz
# Processing Record 33 of Set 7 | bilma
# Processing Record 34 of Set 7 | zhengjiatun
# Processing Record 35 of Set 7 | kushima
# Processing Record 36 of Set 7 | kirakira
# Processing Record 37 of Set 7 | areka
# Processing Record 38 of Set 7 | cabo san lucas
# Processing Record 39 of Set 7 | taitung
# Processing Record 40 of Set 7 | itarema
# Processing Record 41 of Set 7 | singkang
# Processing Record 42 of Set 7 | grants
# Processing Record 43 of Set 7 | yekaterinovka
# Processing Record 44 of Set 7 | bud
# Processing Record 45 of Set 7 | asfi
# Processing Record 46 of Set 7 | fairbanks
# Processing Record 47 of Set 7 | bowen
# Processing Record 48 of Set 7 | tessalit
# Processing Record 49 of Set 7 | lundazi
# Processing Record 50 of Set 7 | severo-kurilsk
# Processing Record 1 of Set 8 | meadow lake
# Processing Record 2 of Set 8 | van
# Processing Record 3 of Set 8 | puro
# Processing Record 4 of Set 8 | kargil
# Processing Record 5 of Set 8 | tilichiki
# Processing Record 6 of Set 8 | honiara
# Processing Record 7 of Set 8 | aksu
# Processing Record 8 of Set 8 | kraskino
# Processing Record 9 of Set 8 | pisco
# Processing Record 10 of Set 8 | nakamura
# Processing Record 11 of Set 8 | shipunovo
# Processing Record 12 of Set 8 | luderitz
# Processing Record 13 of Set 8 | winchester
# Processing Record 14 of Set 8 | maymanak
# City not found. Skipping...
# Processing Record 15 of Set 8 | telimele
# Processing Record 16 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 17 of Set 8 | benghazi
# Processing Record 18 of Set 8 | lumeje
# Processing Record 19 of Set 8 | shingu
# Processing Record 20 of Set 8 | urumqi
# Processing Record 21 of Set 8 | guerrero negro
# Processing Record 22 of Set 8 | bashmakovo
# Processing Record 23 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 8 | iqaluit
# Processing Record 25 of Set 8 | antipovka
# Processing Record 26 of Set 8 | aklavik
# Processing Record 27 of Set 8 | kalabo
# Processing Record 28 of Set 8 | ochamchira
# Processing Record 29 of Set 8 | xichang
# Processing Record 30 of Set 8 | cockburn town
# Processing Record 31 of Set 8 | yerbogachen
# Processing Record 32 of Set 8 | port hardy
# Processing Record 33 of Set 8 | lisakovsk
# Processing Record 34 of Set 8 | saint-ambroise
# Processing Record 35 of Set 8 | katsuura
# Processing Record 36 of Set 8 | alta floresta
# Processing Record 37 of Set 8 | porto novo
# Processing Record 38 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 39 of Set 8 | raudeberg
# Processing Record 40 of Set 8 | tiznit
# Processing Record 41 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 8 | la libertad
# Processing Record 43 of Set 8 | kavieng
# Processing Record 44 of Set 8 | mossendjo
# Processing Record 45 of Set 8 | barra da estiva
# Processing Record 46 of Set 8 | syracuse
# Processing Record 47 of Set 8 | coahuayana
# Processing Record 48 of Set 8 | nyurba
# Processing Record 49 of Set 8 | yola
# Processing Record 50 of Set 8 | umm lajj
# Processing Record 1 of Set 9 | samarai
# Processing Record 2 of Set 9 | cabinda
# Processing Record 3 of Set 9 | pimentel
# Processing Record 4 of Set 9 | sao felix do xingu
# Processing Record 5 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 9 | linguere
# Processing Record 7 of Set 9 | kajaani
# Processing Record 8 of Set 9 | tabuk
# Processing Record 9 of Set 9 | kahului
# Processing Record 10 of Set 9 | noumea
# Processing Record 11 of Set 9 | yenotayevka
# Processing Record 12 of Set 9 | mosquera
# Processing Record 13 of Set 9 | malakal
# Processing Record 14 of Set 9 | svetlogorsk
# Processing Record 15 of Set 9 | palu
# Processing Record 16 of Set 9 | salinas
# Processing Record 17 of Set 9 | lafia
# Processing Record 18 of Set 9 | bardiyah
# Processing Record 19 of Set 9 | swan hill
# Processing Record 20 of Set 9 | matiri
# Processing Record 21 of Set 9 | drochia
# Processing Record 22 of Set 9 | san policarpo
# Processing Record 23 of Set 9 | hailey
# Processing Record 24 of Set 9 | lahat
# Processing Record 25 of Set 9 | trairi
# Processing Record 26 of Set 9 | banyo
# Processing Record 27 of Set 9 | dalbandin
# Processing Record 28 of Set 9 | marienburg
# Processing Record 29 of Set 9 | rehoboth
# Processing Record 30 of Set 9 | codrington
# Processing Record 31 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 9 | joshimath
# Processing Record 33 of Set 9 | chapais
# Processing Record 34 of Set 9 | karratha
# Processing Record 35 of Set 9 | bayan
# Processing Record 36 of Set 9 | yaan
# Processing Record 37 of Set 9 | san quintin
# Processing Record 38 of Set 9 | lavrentiya
# Processing Record 39 of Set 9 | sao filipe
# Processing Record 40 of Set 9 | necochea
# Processing Record 41 of Set 9 | lata
# Processing Record 42 of Set 9 | omsukchan
# Processing Record 43 of Set 9 | harpalpur
# Processing Record 44 of Set 9 | mahajanga
# Processing Record 45 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 9 | simpang
# Processing Record 47 of Set 9 | nago
# Processing Record 48 of Set 9 | villarrica
# Processing Record 49 of Set 9 | lazarev
# Processing Record 50 of Set 9 | mandalgovi
# Processing Record 1 of Set 10 | douentza
# Processing Record 2 of Set 10 | fortuna
# Processing Record 3 of Set 10 | sayyan
# Processing Record 4 of Set 10 | ribeira grande
# Processing Record 5 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 6 of Set 10 | acarau
# Processing Record 7 of Set 10 | namatanai
# Processing Record 8 of Set 10 | nigrita
# Processing Record 9 of Set 10 | dunedin
# Processing Record 10 of Set 10 | rio muerto
# Processing Record 11 of Set 10 | ossora
# Processing Record 12 of Set 10 | salinopolis
# Processing Record 13 of Set 10 | chipata
# Processing Record 14 of Set 10 | koupela
# Processing Record 15 of Set 10 | ponta delgada
# Processing Record 16 of Set 10 | ziarat
# Processing Record 17 of Set 10 | pingdingshan
# Processing Record 18 of Set 10 | portland
# Processing Record 19 of Set 10 | mirnyy
# Processing Record 20 of Set 10 | viedma
# Processing Record 21 of Set 10 | kamaishi
# Processing Record 22 of Set 10 | shalinskoye
# Processing Record 23 of Set 10 | lasa
# Processing Record 24 of Set 10 | cascais
# Processing Record 25 of Set 10 | coronel mariduena
# City not found. Skipping...
# Processing Record 26 of Set 10 | takoradi
# Processing Record 27 of Set 10 | ostrovnoy
# Processing Record 28 of Set 10 | tari
# Processing Record 29 of Set 10 | nome
# Processing Record 30 of Set 10 | louis trichardt
# Processing Record 31 of Set 10 | tezpur
# Processing Record 32 of Set 10 | mpraeso
# Processing Record 33 of Set 10 | bosaso
# Processing Record 34 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 10 | libertador general san martin
# Processing Record 36 of Set 10 | kortkeros
# Processing Record 37 of Set 10 | nicoya
# Processing Record 38 of Set 10 | tairua
# Processing Record 39 of Set 10 | torzhok
# Processing Record 40 of Set 10 | moissala
# Processing Record 41 of Set 10 | mizan teferi
# Processing Record 42 of Set 10 | vilcun
# Processing Record 43 of Set 10 | mitsamiouli
# Processing Record 44 of Set 10 | namibe
# Processing Record 45 of Set 10 | general pico
# Processing Record 46 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 10 | haverfordwest
# Processing Record 48 of Set 10 | rio cuarto
# Processing Record 49 of Set 10 | zhangye
# Processing Record 50 of Set 10 | inhambane
# Processing Record 1 of Set 11 | behshahr
# Processing Record 2 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 3 of Set 11 | kaeo
# Processing Record 4 of Set 11 | ilheus
# Processing Record 5 of Set 11 | cidreira
# Processing Record 6 of Set 11 | georgiyevka
# Processing Record 7 of Set 11 | nalobikha
# Processing Record 8 of Set 11 | chipinge
# Processing Record 9 of Set 11 | cururupu
# Processing Record 10 of Set 11 | teguldet
# Processing Record 11 of Set 11 | kashary
# Processing Record 12 of Set 11 | kautokeino
# Processing Record 13 of Set 11 | mitchell
# Processing Record 14 of Set 11 | bullhead city
# Processing Record 15 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 11 | nagato
# Processing Record 17 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 11 | carnduff
# Processing Record 19 of Set 11 | iroquois falls
# Processing Record 20 of Set 11 | praia
# Processing Record 21 of Set 11 | luba
# Processing Record 22 of Set 11 | waipawa
# Processing Record 23 of Set 11 | surgut
# Processing Record 24 of Set 11 | asau
# Processing Record 25 of Set 11 | visakhapatnam
# Processing Record 26 of Set 11 | eenhana
# Processing Record 27 of Set 11 | zharkent
# Processing Record 28 of Set 11 | eureka
# Processing Record 29 of Set 11 | araouane
# Processing Record 30 of Set 11 | bosobolo
# Processing Record 31 of Set 11 | porto seguro
# Processing Record 32 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 11 | avera
# Processing Record 34 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 11 | iseyin
# Processing Record 36 of Set 11 | port augusta
# Processing Record 37 of Set 11 | salalah
# Processing Record 38 of Set 11 | gobabis
# Processing Record 39 of Set 11 | altamont
# Processing Record 40 of Set 11 | sibu
# Processing Record 41 of Set 11 | opelika
# Processing Record 42 of Set 11 | nisia floresta
# Processing Record 43 of Set 11 | dong xoai
# Processing Record 44 of Set 11 | nyzy
# Processing Record 45 of Set 11 | berezovyy
# Processing Record 46 of Set 11 | chegdomyn
# Processing Record 47 of Set 11 | mahibadhoo
# Processing Record 48 of Set 11 | manzanillo
# Processing Record 49 of Set 11 | mae hong son
# Processing Record 50 of Set 11 | grindavik
# Processing Record 1 of Set 12 | devils lake
# Processing Record 2 of Set 12 | richards bay
# Processing Record 3 of Set 12 | bo phloi
# Processing Record 4 of Set 12 | sharjah
# Processing Record 5 of Set 12 | banepa
# Processing Record 6 of Set 12 | sinnamary
# Processing Record 7 of Set 12 | hastings
# Processing Record 8 of Set 12 | sur
# Processing Record 9 of Set 12 | chicama
# Processing Record 10 of Set 12 | paamiut
# Processing Record 11 of Set 12 | sungaipenuh
# Processing Record 12 of Set 12 | pochutla
# Processing Record 13 of Set 12 | santo tomas
# Processing Record 14 of Set 12 | saint-joseph
# Processing Record 15 of Set 12 | havelock
# Processing Record 16 of Set 12 | san jose
# Processing Record 17 of Set 12 | buarcos
# Processing Record 18 of Set 12 | biak
# Processing Record 19 of Set 12 | agirish
# Processing Record 20 of Set 12 | udachnyy
# Processing Record 21 of Set 12 | la ronge
# Processing Record 22 of Set 12 | santa maria
# Processing Record 23 of Set 12 | ola
# Processing Record 24 of Set 12 | arkhipo-osipovka
# Processing Record 25 of Set 12 | eurajoki
# Processing Record 26 of Set 12 | garowe
# Processing Record 27 of Set 12 | hambantota
# Processing Record 28 of Set 12 | trelew
# Processing Record 29 of Set 12 | zarinsk
# Processing Record 30 of Set 12 | ruteng
# Processing Record 31 of Set 12 | chapada dos guimaraes
# Processing Record 32 of Set 12 | freetown
# Processing Record 33 of Set 12 | melilla
# Processing Record 34 of Set 12 | mamlyutka
# Processing Record 35 of Set 12 | rudkobing
# Processing Record 36 of Set 12 | cubuk
# Processing Record 37 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 12 | okha
# Processing Record 39 of Set 12 | rocha
# Processing Record 40 of Set 12 | beloha
# Processing Record 41 of Set 12 | margate
# Processing Record 42 of Set 12 | pouebo
# Processing Record 43 of Set 12 | porbandar
# Processing Record 44 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 12 | baudh
# Processing Record 46 of Set 12 | bom jesus do itabapoana
# Processing Record 47 of Set 12 | praia da vitoria
# Processing Record 48 of Set 12 | puerto baquerizo moreno
# Processing Record 49 of Set 12 | tashla
# Processing Record 50 of Set 12 | tocopilla
# Processing Record 1 of Set 13 | kollam
# Processing Record 2 of Set 13 | kidal
# Processing Record 3 of Set 13 | balikpapan
# Processing Record 4 of Set 13 | zemio
# Processing Record 5 of Set 13 | shebunino
# Processing Record 6 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 13 | akdepe
# Processing Record 8 of Set 13 | talant
# Processing Record 9 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 10 of Set 13 | evensk
# Processing Record 11 of Set 13 | walvis bay
# Processing Record 12 of Set 13 | ugoofaaru
# Processing Record 13 of Set 13 | stromness
# Processing Record 14 of Set 13 | panguna
# Processing Record 15 of Set 13 | biltine
# Processing Record 16 of Set 13 | olivenza
# Processing Record 17 of Set 13 | deyang
# Processing Record 18 of Set 13 | sabya
# Processing Record 19 of Set 13 | khuzhir
# Processing Record 20 of Set 13 | oxapampa
# Processing Record 21 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 13 | otjimbingwe
# Processing Record 23 of Set 13 | nadym
# Processing Record 24 of Set 13 | chibombo
# Processing Record 25 of Set 13 | kununurra
# Processing Record 26 of Set 13 | balkanabat
# Processing Record 27 of Set 13 | deputatskiy
# Processing Record 28 of Set 13 | abu samrah
# Processing Record 29 of Set 13 | blackwater
# Processing Record 30 of Set 13 | chegutu
# Processing Record 31 of Set 13 | turukhansk
# Processing Record 32 of Set 13 | tobolsk
# Processing Record 33 of Set 13 | henties bay
# Processing Record 34 of Set 13 | sumenep
# Processing Record 35 of Set 13 | mvomero
# Processing Record 36 of Set 13 | karachi
# Processing Record 37 of Set 13 | kizhinga
# Processing Record 38 of Set 13 | sidi ali
# Processing Record 39 of Set 13 | nishihara
# Processing Record 40 of Set 13 | los llanos de aridane
# Processing Record 41 of Set 13 | ballina
# Processing Record 42 of Set 13 | aswan
# Processing Record 43 of Set 13 | muros
# Processing Record 44 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 13 | sawtell
# Processing Record 46 of Set 13 | nexo
# Processing Record 47 of Set 13 | shelbyville
# Processing Record 48 of Set 13 | vulcan
# Processing Record 49 of Set 13 | antofagasta
# Processing Record 50 of Set 13 | yagodnoye
# Processing Record 1 of Set 14 | yar-sale
# Processing Record 2 of Set 14 | dudinka
# Processing Record 3 of Set 14 | taoudenni
# Processing Record 4 of Set 14 | chara
# Processing Record 5 of Set 14 | kemi
# Processing Record 6 of Set 14 | kutum
# Processing Record 7 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 14 | nordlingen
# City not found. Skipping...
# Processing Record 9 of Set 14 | ewa beach
# Processing Record 10 of Set 14 | roebourne
# Processing Record 11 of Set 14 | dongsheng
# Processing Record 12 of Set 14 | porto santo
# Processing Record 13 of Set 14 | gravelbourg
# Processing Record 14 of Set 14 | verkhoyansk
# Processing Record 15 of Set 14 | lompoc
# Processing Record 16 of Set 14 | promissao
# Processing Record 17 of Set 14 | minab
# Processing Record 18 of Set 14 | port said
# Processing Record 19 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 20 of Set 14 | goure
# Processing Record 21 of Set 14 | shenjiamen
# Processing Record 22 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 14 | college
# Processing Record 24 of Set 14 | vestmannaeyjar
# Processing Record 25 of Set 14 | davila
# Processing Record 26 of Set 14 | atambua
# Processing Record 27 of Set 14 | xucheng
# Processing Record 28 of Set 14 | grafton
# Processing Record 29 of Set 14 | sabha
# Processing Record 30 of Set 14 | masty
# Processing Record 31 of Set 14 | haines junction
# Processing Record 32 of Set 14 | vinh
# Processing Record 33 of Set 14 | hun
# Processing Record 34 of Set 14 | zhigansk
# Processing Record 35 of Set 14 | huarmey
# Processing Record 36 of Set 14 | monduli
# Processing Record 37 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 14 | aykhal
# Processing Record 39 of Set 14 | nizhniy tsasuchey
# Processing Record 40 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 14 | paka
# Processing Record 42 of Set 14 | manokwari
# Processing Record 43 of Set 14 | edgewood
# Processing Record 44 of Set 14 | abeche
# Processing Record 45 of Set 14 | shivrajpur
# Processing Record 46 of Set 14 | punalur
# Processing Record 47 of Set 14 | boende
# Processing Record 48 of Set 14 | kachiry
# Processing Record 49 of Set 14 | ponazyrevo
# Processing Record 50 of Set 14 | dovers
# Processing Record 1 of Set 15 | kholmogory
# Processing Record 2 of Set 15 | mastic beach
# Processing Record 3 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 4 of Set 15 | wajir
# Processing Record 5 of Set 15 | inirida
# Processing Record 6 of Set 15 | nelson bay
# Processing Record 7 of Set 15 | terra santa
# Processing Record 8 of Set 15 | biloela
# Processing Record 9 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 15 | taua
# Processing Record 11 of Set 15 | lanja
# Processing Record 12 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 15 | outjo
# Processing Record 14 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 15 | kieta
# Processing Record 16 of Set 15 | malim
# Processing Record 17 of Set 15 | camacha
# Processing Record 18 of Set 15 | saint-pierre
# Processing Record 19 of Set 15 | moa
# Processing Record 20 of Set 15 | san vicente
# Processing Record 21 of Set 15 | tautira
# Processing Record 22 of Set 15 | murdochville
# Processing Record 23 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 15 | baiyin
# Processing Record 25 of Set 15 | ulladulla
# Processing Record 26 of Set 15 | praia grande
# Processing Record 27 of Set 15 | andros town
# Processing Record 28 of Set 15 | ainazi
# Processing Record 29 of Set 15 | vao
# Processing Record 30 of Set 15 | wexford
# Processing Record 31 of Set 15 | platanos
# Processing Record 32 of Set 15 | alcantara
# Processing Record 33 of Set 15 | payo
# Processing Record 34 of Set 15 | fougamou
# Processing Record 35 of Set 15 | shizunai
# Processing Record 36 of Set 15 | morristown
# Processing Record 37 of Set 15 | el alto
# Processing Record 38 of Set 15 | lubao
# Processing Record 39 of Set 15 | smithers
# Processing Record 40 of Set 15 | vaovai
# City not found. Skipping...
# Processing Record 41 of Set 15 | ekhabi
# Processing Record 42 of Set 15 | chiang khong
# Processing Record 43 of Set 15 | xuanhua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dicts to a pd df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Poum      NC -20.2333  164.0167     76.42        70           9
# 1        Avarua      CK -21.2078 -159.7750     78.85        65          75
# 2        Albany      US  42.6001  -73.9662     50.61        72          24
# 3  Punta Arenas      CL -53.1500  -70.9167     48.31        49          40
# 4        Takaka      NZ -40.8500  172.8000     64.56        53           6
# 5        Bonthe      SL   7.5264  -12.5050     76.33        89         100
# 6       Fernley      US  39.6080 -119.2518     73.51        36          35
# 7        Atuona      PF  -9.8000 -139.0333     77.38        72          24
# 8       Labuhan      ID  -6.8844  112.2051     81.66        78         100
# 9       Shakawe      BW -18.3667   21.8500     75.96        49          40
#
#    Wind Speed Current Description
# 0       12.86           clear sky
# 1       12.66       broken clouds
# 2        1.99          few clouds
# 3       18.41    scattered clouds
# 4       10.83           clear sky
# 5        7.74       moderate rain
# 6        3.00    scattered clouds
# 7       12.39          few clouds
# 8        9.40     overcast clouds
# 9        0.78    scattered clouds

# %%
#create output csv file
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#export the City_Data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
